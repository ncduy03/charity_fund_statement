# %%
import pdfplumber
import csv
import re

# %%
input_file_path = "../data/raw_data/vcb_data.pdf"
output_file_path = "../data/processed_data/transactions.csv"

# %%
with pdfplumber.open(input_file_path) as pdf:
    num_pages = len(pdf.pages)
    print(f"The PDF file contains {num_pages} pages.")
# Out:
# The PDF file contains 12028 pages.

# %%
header = ["date", "credit", "transaction_detail", "transaction_id"]

with open(output_file_path, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.DictWriter(file, fieldnames=header)
    writer.writeheader()

# %%
def parse_transactions(page_text):
    pattern = r"(\d{2}/\d{2}/\d{4})\s+([\d.,]+)\s+([\s\S]+?)(?=(\d{2}/\d{2}/\d{4})|$)"
    matches = re.finditer(pattern, page_text.strip())
    
    transactions = []
    for match in matches:
        date = match.group(1).strip() 
        credit = match.group(2).strip()  
        transaction_detail = match.group(3).strip()  

        lines = transaction_detail.split("\n")
        if len(lines) > 1:
            transaction_id = lines[1].strip() 
            transaction_detail = f"{lines[0]} {''.join(lines[2:])}".strip()
        else:
            transaction_id = "" 

        transactions.append({
            "date": date,
            "credit": credit,
            "transaction_detail": transaction_detail,
            "transaction_id": transaction_id,
        })
    return transactions

# %%
def clean_transaction_detail(transaction):
    keywords = ["Postal address", "Telex", "Page", "Website", "Contact center", "Swift"]
    
    for keyword in keywords:
        if keyword in transaction["transaction_detail"]:
            transaction["transaction_detail"] = transaction["transaction_detail"].split(keyword)[0].strip()
            break  
    
    return transaction

# %%
def write_to_csv(transactions):
    with open(output_file_path, mode="a", newline="", encoding="utf-8") as file:
        writer = csv.DictWriter(file, fieldnames=header)
        for transaction in transactions:
            writer.writerow(transaction)

# %%
start_page = 11001
end_page = 13000

all_transactions = []

with pdfplumber.open(input_file_path) as pdf:
    total_pages = len(pdf.pages)
    
    start_page = max(1, start_page)
    end_page = min(total_pages, end_page)  
    
    for i in range(start_page - 1, end_page):
        print(f"Processing page {i + 1}")
        text = pdf.pages[i].extract_text()
        transactions = parse_transactions(text)
        cleaned_transactions = [clean_transaction_detail(t) for t in transactions]
        all_transactions.extend(cleaned_transactions)
        
        write_to_csv(cleaned_transactions)
        all_transactions = []

print(f"Successfully processed and saved all transactions to the file {output_file_path}")
# Out:
# Processing page 11001
# Processing page 11002
# Processing page 11003
# Processing page 11004
# Processing page 11005
# Processing page 11006
# Processing page 11007
# Processing page 11008
# Processing page 11009
# Processing page 11010
# Processing page 11011
# Processing page 11012
# Processing page 11013
# Processing page 11014
# Processing page 11015
# Processing page 11016
# Processing page 11017
# Processing page 11018
# Processing page 11019
# Processing page 11020
# Processing page 11021
# Processing page 11022
# Processing page 11023
# Processing page 11024
# Processing page 11025
# Processing page 11026
# Processing page 11027
# Processing page 11028
# Processing page 11029
# Processing page 11030
# Processing page 11031
# Processing page 11032
# Processing page 11033
# Processing page 11034
# Processing page 11035
# Processing page 11036
# Processing page 11037
# Processing page 11038
# Processing page 11039
# Processing page 11040
# Processing page 11041
# Processing page 11042
# Processing page 11043
# Processing page 11044
# Processing page 11045
# Processing page 11046
# Processing page 11047
# Processing page 11048
# Processing page 11049
# Processing page 11050
# Processing page 11051
# Processing page 11052
# Processing page 11053
# Processing page 11054
# Processing page 11055
# Processing page 11056
# Processing page 11057
# Processing page 11058
# Processing page 11059
# Processing page 11060
# Processing page 11061
# Processing page 11062
# Processing page 11063
# Processing page 11064
# Processing page 11065
# Processing page 11066
# Processing page 11067
# Processing page 11068
# Processing page 11069
# Processing page 11070
# Processing page 11071
# Processing page 11072
# Processing page 11073
# Processing page 11074
# Processing page 11075
# Processing page 11076
# Processing page 11077
# Processing page 11078
# Processing page 11079
# Processing page 11080
# Processing page 11081
# Processing page 11082
# Processing page 11083
# Processing page 11084
# Processing page 11085
# Processing page 11086
# Processing page 11087
# Processing page 11088
# Processing page 11089
# Processing page 11090
# Processing page 11091
# Processing page 11092
# Processing page 11093
# Processing page 11094
# Processing page 11095
# Processing page 11096
# Processing page 11097
# Processing page 11098
# Processing page 11099
# Processing page 11100
# Processing page 11101
# Processing page 11102
# Processing page 11103
# Processing page 11104
# Processing page 11105
# Processing page 11106
# Processing page 11107
# Processing page 11108
# Processing page 11109
# Processing page 11110
# Processing page 11111
# Processing page 11112
# Processing page 11113
# Processing page 11114
# Processing page 11115
# Processing page 11116
# Processing page 11117
# Processing page 11118
# Processing page 11119
# Processing page 11120
# Processing page 11121
# Processing page 11122
# Processing page 11123
# Processing page 11124
# Processing page 11125
# Processing page 11126
# Processing page 11127
# Processing page 11128
# Processing page 11129
# Processing page 11130
# Processing page 11131
# Processing page 11132
# Processing page 11133
# Processing page 11134
# Processing page 11135
# Processing page 11136
# Processing page 11137
# Processing page 11138
# Processing page 11139
# Processing page 11140
# Processing page 11141
# Processing page 11142
# Processing page 11143
# Processing page 11144
# Processing page 11145
# Processing page 11146
# Processing page 11147
# Processing page 11148
# Processing page 11149
# Processing page 11150
# Processing page 11151
# Processing page 11152
# Processing page 11153
# Processing page 11154
# Processing page 11155
# Processing page 11156
# Processing page 11157
# Processing page 11158
# Processing page 11159
# Processing page 11160
# Processing page 11161
# Processing page 11162
# Processing page 11163
# Processing page 11164
# Processing page 11165
# Processing page 11166
# Processing page 11167
# Processing page 11168
# Processing page 11169
# Processing page 11170
# Processing page 11171
# Processing page 11172
# Processing page 11173
# Processing page 11174
# Processing page 11175
# Processing page 11176
# Processing page 11177
# Processing page 11178
# Processing page 11179
# Processing page 11180
# Processing page 11181
# Processing page 11182
# Processing page 11183
# Processing page 11184
# Processing page 11185
# Processing page 11186
# Processing page 11187
# Processing page 11188
# Processing page 11189
# Processing page 11190
# Processing page 11191
# Processing page 11192
# Processing page 11193
# Processing page 11194
# Processing page 11195
# Processing page 11196
# Processing page 11197
# Processing page 11198
# Processing page 11199
# Processing page 11200
# Processing page 11201
# Processing page 11202
# Processing page 11203
# Processing page 11204
# Processing page 11205
# Processing page 11206
# Processing page 11207
# Processing page 11208
# Processing page 11209
# Processing page 11210
# Processing page 11211
# Processing page 11212
# Processing page 11213
# Processing page 11214
# Processing page 11215
# Processing page 11216
# Processing page 11217
# Processing page 11218
# Processing page 11219
# Processing page 11220
# Processing page 11221
# Processing page 11222
# Processing page 11223
# Processing page 11224
# Processing page 11225
# Processing page 11226
# Processing page 11227
# Processing page 11228
# Processing page 11229
# Processing page 11230
# Processing page 11231
# Processing page 11232
# Processing page 11233
# Processing page 11234
# Processing page 11235
# Processing page 11236
# Processing page 11237
# Processing page 11238
# Processing page 11239
# Processing page 11240
# Processing page 11241
# Processing page 11242
# Processing page 11243
# Processing page 11244
# Processing page 11245
# Processing page 11246
# Processing page 11247
# Processing page 11248
# Processing page 11249
# Processing page 11250
# Processing page 11251
# Processing page 11252
# Processing page 11253
# Processing page 11254
# Processing page 11255
# Processing page 11256
# Processing page 11257
# Processing page 11258
# Processing page 11259
# Processing page 11260
# Processing page 11261
# Processing page 11262
# Processing page 11263
# Processing page 11264
# Processing page 11265
# Processing page 11266
# Processing page 11267
# Processing page 11268
# Processing page 11269
# Processing page 11270
# Processing page 11271
# Processing page 11272
# Processing page 11273
# Processing page 11274
# Processing page 11275
# Processing page 11276
# Processing page 11277
# Processing page 11278
# Processing page 11279
# Processing page 11280
# Processing page 11281
# Processing page 11282
# Processing page 11283
# Processing page 11284
# Processing page 11285
# Processing page 11286
# Processing page 11287
# Processing page 11288
# Processing page 11289
# Processing page 11290
# Processing page 11291
# Processing page 11292
# Processing page 11293
# Processing page 11294
# Processing page 11295
# Processing page 11296
# Processing page 11297
# Processing page 11298
# Processing page 11299
# Processing page 11300
# Processing page 11301
# Processing page 11302
# Processing page 11303
# Processing page 11304
# Processing page 11305
# Processing page 11306
# Processing page 11307
# Processing page 11308
# Processing page 11309
# Processing page 11310
# Processing page 11311
# Processing page 11312
# Processing page 11313
# Processing page 11314
# Processing page 11315
# Processing page 11316
# Processing page 11317
# Processing page 11318
# Processing page 11319
# Processing page 11320
# Processing page 11321
# Processing page 11322
# Processing page 11323
# Processing page 11324
# Processing page 11325
# Processing page 11326
# Processing page 11327
# Processing page 11328
# Processing page 11329
# Processing page 11330
# Processing page 11331
# Processing page 11332
# Processing page 11333
# Processing page 11334
# Processing page 11335
# Processing page 11336
# Processing page 11337
# Processing page 11338
# Processing page 11339
# Processing page 11340
# Processing page 11341
# Processing page 11342
# Processing page 11343
# Processing page 11344
# Processing page 11345
# Processing page 11346
# Processing page 11347
# Processing page 11348
# Processing page 11349
# Processing page 11350
# Processing page 11351
# Processing page 11352
# Processing page 11353
# Processing page 11354
# Processing page 11355
# Processing page 11356
# Processing page 11357
# Processing page 11358
# Processing page 11359
# Processing page 11360
# Processing page 11361
# Processing page 11362
# Processing page 11363
# Processing page 11364
# Processing page 11365
# Processing page 11366
# Processing page 11367
# Processing page 11368
# Processing page 11369
# Processing page 11370
# Processing page 11371
# Processing page 11372
# Processing page 11373
# Processing page 11374
# Processing page 11375
# Processing page 11376
# Processing page 11377
# Processing page 11378
# Processing page 11379
# Processing page 11380
# Processing page 11381
# Processing page 11382
# Processing page 11383
# Processing page 11384
# Processing page 11385
# Processing page 11386
# Processing page 11387
# Processing page 11388
# Processing page 11389
# Processing page 11390
# Processing page 11391
# Processing page 11392
# Processing page 11393
# Processing page 11394
# Processing page 11395
# Processing page 11396
# Processing page 11397
# Processing page 11398
# Processing page 11399
# Processing page 11400
# Processing page 11401
# Processing page 11402
# Processing page 11403
# Processing page 11404
# Processing page 11405
# Processing page 11406
# Processing page 11407
# Processing page 11408
# Processing page 11409
# Processing page 11410
# Processing page 11411
# Processing page 11412
# Processing page 11413
# Processing page 11414
# Processing page 11415
# Processing page 11416
# Processing page 11417
# Processing page 11418
# Processing page 11419
# Processing page 11420
# Processing page 11421
# Processing page 11422
# Processing page 11423
# Processing page 11424
# Processing page 11425
# Processing page 11426
# Processing page 11427
# Processing page 11428
# Processing page 11429
# Processing page 11430
# Processing page 11431
# Processing page 11432
# Processing page 11433
# Processing page 11434
# Processing page 11435
# Processing page 11436
# Processing page 11437
# Processing page 11438
# Processing page 11439
# Processing page 11440
# Processing page 11441
# Processing page 11442
# Processing page 11443
# Processing page 11444
# Processing page 11445
# Processing page 11446
# Processing page 11447
# Processing page 11448
# Processing page 11449
# Processing page 11450
# Processing page 11451
# Processing page 11452
# Processing page 11453
# Processing page 11454
# Processing page 11455
# Processing page 11456
# Processing page 11457
# Processing page 11458
# Processing page 11459
# Processing page 11460
# Processing page 11461
# Processing page 11462
# Processing page 11463
# Processing page 11464
# Processing page 11465
# Processing page 11466
# Processing page 11467
# Processing page 11468
# Processing page 11469
# Processing page 11470
# Processing page 11471
# Processing page 11472
# Processing page 11473
# Processing page 11474
# Processing page 11475
# Processing page 11476
# Processing page 11477
# Processing page 11478
# Processing page 11479
# Processing page 11480
# Processing page 11481
# Processing page 11482
# Processing page 11483
# Processing page 11484
# Processing page 11485
# Processing page 11486
# Processing page 11487
# Processing page 11488
# Processing page 11489
# Processing page 11490
# Processing page 11491
# Processing page 11492
# Processing page 11493
# Processing page 11494
# Processing page 11495
# Processing page 11496
# Processing page 11497
# Processing page 11498
# Processing page 11499
# Processing page 11500
# Processing page 11501
# Processing page 11502
# Processing page 11503
# Processing page 11504
# Processing page 11505
# Processing page 11506
# Processing page 11507
# Processing page 11508
# Processing page 11509
# Processing page 11510
# Processing page 11511
# Processing page 11512
# Processing page 11513
# Processing page 11514
# Processing page 11515
# Processing page 11516
# Processing page 11517
# Processing page 11518
# Processing page 11519
# Processing page 11520
# Processing page 11521
# Processing page 11522
# Processing page 11523
# Processing page 11524
# Processing page 11525
# Processing page 11526
# Processing page 11527
# Processing page 11528
# Processing page 11529
# Processing page 11530
# Processing page 11531
# Processing page 11532
# Processing page 11533
# Processing page 11534
# Processing page 11535
# Processing page 11536
# Processing page 11537
# Processing page 11538
# Processing page 11539
# Processing page 11540
# Processing page 11541
# Processing page 11542
# Processing page 11543
# Processing page 11544
# Processing page 11545
# Processing page 11546
# Processing page 11547
# Processing page 11548
# Processing page 11549
# Processing page 11550
# Processing page 11551
# Processing page 11552
# Processing page 11553
# Processing page 11554
# Processing page 11555
# Processing page 11556
# Processing page 11557
# Processing page 11558
# Processing page 11559
# Processing page 11560
# Processing page 11561
# Processing page 11562
# Processing page 11563
# Processing page 11564
# Processing page 11565
# Processing page 11566
# Processing page 11567
# Processing page 11568
# Processing page 11569
# Processing page 11570
# Processing page 11571
# Processing page 11572
# Processing page 11573
# Processing page 11574
# Processing page 11575
# Processing page 11576
# Processing page 11577
# Processing page 11578
# Processing page 11579
# Processing page 11580
# Processing page 11581
# Processing page 11582
# Processing page 11583
# Processing page 11584
# Processing page 11585
# Processing page 11586
# Processing page 11587
# Processing page 11588
# Processing page 11589
# Processing page 11590
# Processing page 11591
# Processing page 11592
# Processing page 11593
# Processing page 11594
# Processing page 11595
# Processing page 11596
# Processing page 11597
# Processing page 11598
# Processing page 11599
# Processing page 11600
# Processing page 11601
# Processing page 11602
# Processing page 11603
# Processing page 11604
# Processing page 11605
# Processing page 11606
# Processing page 11607
# Processing page 11608
# Processing page 11609
# Processing page 11610
# Processing page 11611
# Processing page 11612
# Processing page 11613
# Processing page 11614
# Processing page 11615
# Processing page 11616
# Processing page 11617
# Processing page 11618
# Processing page 11619
# Processing page 11620
# Processing page 11621
# Processing page 11622
# Processing page 11623
# Processing page 11624
# Processing page 11625
# Processing page 11626
# Processing page 11627
# Processing page 11628
# Processing page 11629
# Processing page 11630
# Processing page 11631
# Processing page 11632
# Processing page 11633
# Processing page 11634
# Processing page 11635
# Processing page 11636
# Processing page 11637
# Processing page 11638
# Processing page 11639
# Processing page 11640
# Processing page 11641
# Processing page 11642
# Processing page 11643
# Processing page 11644
# Processing page 11645
# Processing page 11646
# Processing page 11647
# Processing page 11648
# Processing page 11649
# Processing page 11650
# Processing page 11651
# Processing page 11652
# Processing page 11653
# Processing page 11654
# Processing page 11655
# Processing page 11656
# Processing page 11657
# Processing page 11658
# Processing page 11659
# Processing page 11660
# Processing page 11661
# Processing page 11662
# Processing page 11663
# Processing page 11664
# Processing page 11665
# Processing page 11666
# Processing page 11667
# Processing page 11668
# Processing page 11669
# Processing page 11670
# Processing page 11671
# Processing page 11672
# Processing page 11673
# Processing page 11674
# Processing page 11675
# Processing page 11676
# Processing page 11677
# Processing page 11678
# Processing page 11679
# Processing page 11680
# Processing page 11681
# Processing page 11682
# Processing page 11683
# Processing page 11684
# Processing page 11685
# Processing page 11686
# Processing page 11687
# Processing page 11688
# Processing page 11689
# Processing page 11690
# Processing page 11691
# Processing page 11692
# Processing page 11693
# Processing page 11694
# Processing page 11695
# Processing page 11696
# Processing page 11697
# Processing page 11698
# Processing page 11699
# Processing page 11700
# Processing page 11701
# Processing page 11702
# Processing page 11703
# Processing page 11704
# Processing page 11705
# Processing page 11706
# Processing page 11707
# Processing page 11708
# Processing page 11709
# Processing page 11710
# Processing page 11711
# Processing page 11712
# Processing page 11713
# Processing page 11714
# Processing page 11715
# Processing page 11716
# Processing page 11717
# Processing page 11718
# Processing page 11719
# Processing page 11720
# Processing page 11721
# Processing page 11722
# Processing page 11723
# Processing page 11724
# Processing page 11725
# Processing page 11726
# Processing page 11727
# Processing page 11728
# Processing page 11729
# Processing page 11730
# Processing page 11731
# Processing page 11732
# Processing page 11733
# Processing page 11734
# Processing page 11735
# Processing page 11736
# Processing page 11737
# Processing page 11738
# Processing page 11739
# Processing page 11740
# Processing page 11741
# Processing page 11742
# Processing page 11743
# Processing page 11744
# Processing page 11745
# Processing page 11746
# Processing page 11747
# Processing page 11748
# Processing page 11749
# Processing page 11750
# Processing page 11751
# Processing page 11752
# Processing page 11753
# Processing page 11754
# Processing page 11755
# Processing page 11756
# Processing page 11757
# Processing page 11758
# Processing page 11759
# Processing page 11760
# Processing page 11761
# Processing page 11762
# Processing page 11763
# Processing page 11764
# Processing page 11765
# Processing page 11766
# Processing page 11767
# Processing page 11768
# Processing page 11769
# Processing page 11770
# Processing page 11771
# Processing page 11772
# Processing page 11773
# Processing page 11774
# Processing page 11775
# Processing page 11776
# Processing page 11777
# Processing page 11778
# Processing page 11779
# Processing page 11780
# Processing page 11781
# Processing page 11782
# Processing page 11783
# Processing page 11784
# Processing page 11785
# Processing page 11786
# Processing page 11787
# Processing page 11788
# Processing page 11789
# Processing page 11790
# Processing page 11791
# Processing page 11792
# Processing page 11793
# Processing page 11794
# Processing page 11795
# Processing page 11796
# Processing page 11797
# Processing page 11798
# Processing page 11799
# Processing page 11800
# Processing page 11801
# Processing page 11802
# Processing page 11803
# Processing page 11804
# Processing page 11805
# Processing page 11806
# Processing page 11807
# Processing page 11808
# Processing page 11809
# Processing page 11810
# Processing page 11811
# Processing page 11812
# Processing page 11813
# Processing page 11814
# Processing page 11815
# Processing page 11816
# Processing page 11817
# Processing page 11818
# Processing page 11819
# Processing page 11820
# Processing page 11821
# Processing page 11822
# Processing page 11823
# Processing page 11824
# Processing page 11825
# Processing page 11826
# Processing page 11827
# Processing page 11828
# Processing page 11829
# Processing page 11830
# Processing page 11831
# Processing page 11832
# Processing page 11833
# Processing page 11834
# Processing page 11835
# Processing page 11836
# Processing page 11837
# Processing page 11838
# Processing page 11839
# Processing page 11840
# Processing page 11841
# Processing page 11842
# Processing page 11843
# Processing page 11844
# Processing page 11845
# Processing page 11846
# Processing page 11847
# Processing page 11848
# Processing page 11849
# Processing page 11850
# Processing page 11851
# Processing page 11852
# Processing page 11853
# Processing page 11854
# Processing page 11855
# Processing page 11856
# Processing page 11857
# Processing page 11858
# Processing page 11859
# Processing page 11860
# Processing page 11861
# Processing page 11862
# Processing page 11863
# Processing page 11864
# Processing page 11865
# Processing page 11866
# Processing page 11867
# Processing page 11868
# Processing page 11869
# Processing page 11870
# Processing page 11871
# Processing page 11872
# Processing page 11873
# Processing page 11874
# Processing page 11875
# Processing page 11876
# Processing page 11877
# Processing page 11878
# Processing page 11879
# Processing page 11880
# Processing page 11881
# Processing page 11882
# Processing page 11883
# Processing page 11884
# Processing page 11885
# Processing page 11886
# Processing page 11887
# Processing page 11888
# Processing page 11889
# Processing page 11890
# Processing page 11891
# Processing page 11892
# Processing page 11893
# Processing page 11894
# Processing page 11895
# Processing page 11896
# Processing page 11897
# Processing page 11898
# Processing page 11899
# Processing page 11900
# Processing page 11901
# Processing page 11902
# Processing page 11903
# Processing page 11904
# Processing page 11905
# Processing page 11906
# Processing page 11907
# Processing page 11908
# Processing page 11909
# Processing page 11910
# Processing page 11911
# Processing page 11912
# Processing page 11913
# Processing page 11914
# Processing page 11915
# Processing page 11916
# Processing page 11917
# Processing page 11918
# Processing page 11919
# Processing page 11920
# Processing page 11921
# Processing page 11922
# Processing page 11923
# Processing page 11924
# Processing page 11925
# Processing page 11926
# Processing page 11927
# Processing page 11928
# Processing page 11929
# Processing page 11930
# Processing page 11931
# Processing page 11932
# Processing page 11933
# Processing page 11934
# Processing page 11935
# Processing page 11936
# Processing page 11937
# Processing page 11938
# Processing page 11939
# Processing page 11940
# Processing page 11941
# Processing page 11942
# Processing page 11943
# Processing page 11944
# Processing page 11945
# Processing page 11946
# Processing page 11947
# Processing page 11948
# Processing page 11949
# Processing page 11950
# Processing page 11951
# Processing page 11952
# Processing page 11953
# Processing page 11954
# Processing page 11955
# Processing page 11956
# Processing page 11957
# Processing page 11958
# Processing page 11959
# Processing page 11960
# Processing page 11961
# Processing page 11962
# Processing page 11963
# Processing page 11964
# Processing page 11965
# Processing page 11966
# Processing page 11967
# Processing page 11968
# Processing page 11969
# Processing page 11970
# Processing page 11971
# Processing page 11972
# Processing page 11973
# Processing page 11974
# Processing page 11975
# Processing page 11976
# Processing page 11977
# Processing page 11978
# Processing page 11979
# Processing page 11980
# Processing page 11981
# Processing page 11982
# Processing page 11983
# Processing page 11984
# Processing page 11985
# Processing page 11986
# Processing page 11987
# Processing page 11988
# Processing page 11989
# Processing page 11990
# Processing page 11991
# Processing page 11992
# Processing page 11993
# Processing page 11994
# Processing page 11995
# Processing page 11996
# Processing page 11997
# Processing page 11998
# Processing page 11999
# Processing page 12000
# Processing page 12001
# Processing page 12002
# Processing page 12003
# Processing page 12004
# Processing page 12005
# Processing page 12006
# Processing page 12007
# Processing page 12008
# Processing page 12009
# Processing page 12010
# Processing page 12011
# Processing page 12012
# Processing page 12013
# Processing page 12014
# Processing page 12015
# Processing page 12016
# Processing page 12017
# Processing page 12018
# Processing page 12019
# Processing page 12020
# Processing page 12021
# Processing page 12022
# Processing page 12023
# Processing page 12024
# Processing page 12025
# Processing page 12026
# Processing page 12027
# Processing page 12028
# Successfully processed and saved all transactions to the file ../data/processed_data/transactions_1.csv
