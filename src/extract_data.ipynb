# %%
import pdfplumber
import csv
import re

# %%
input_file_path = "../data/raw_data/vcb_data.pdf"
output_file_path = "../data/processed_data/transactions.csv"

# %%
with pdfplumber.open(input_file_path) as pdf:
    num_pages = len(pdf.pages)
    print(f"The PDF file contains {num_pages} pages.")
# Out:
# The PDF file contains 12028 pages.

# %%
header = ["date", "credit", "transaction_detail", "transaction_id"]

with open(output_file_path, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.DictWriter(file, fieldnames=header)
    writer.writeheader()

# %%
def parse_transactions(page_text):
    pattern = r"(\d{2}/\d{2}/\d{4})\s+([\d.,]+)\s+([\s\S]+?)(?=(\d{2}/\d{2}/\d{4})|$)"
    matches = re.finditer(pattern, page_text.strip())
    
    transactions = []
    for match in matches:
        date = match.group(1).strip() 
        credit = match.group(2).strip()  
        transaction_detail = match.group(3).strip()  

        lines = transaction_detail.split("\n")
        if len(lines) > 1:
            transaction_id = lines[1].strip() 
            transaction_detail = f"{lines[0]} {''.join(lines[2:])}".strip()
        else:
            transaction_id = "" 

        transactions.append({
            "date": date,
            "credit": credit,
            "transaction_detail": transaction_detail,
            "transaction_id": transaction_id,
        })
    return transactions

# %%
def clean_transaction_detail(transaction):
    keywords = ["Postal address", "Telex", "Page", "Website", "Contact center", "Swift"]
    
    for keyword in keywords:
        if keyword in transaction["transaction_detail"]:
            transaction["transaction_detail"] = transaction["transaction_detail"].split(keyword)[0].strip()
            break  
    
    return transaction

# %%
def write_to_csv(transactions):
    with open(output_file_path, mode="a", newline="", encoding="utf-8") as file:
        writer = csv.DictWriter(file, fieldnames=header)
        for transaction in transactions:
            writer.writerow(transaction)

# %%
all_transactions = []

with pdfplumber.open(input_file_path) as pdf:
    for i, page in enumerate(pdf.pages):
        print(f"Processing page {i + 1}")
        text = page.extract_text()   
        transactions = parse_transactions(text)
        cleaned_transactions = [clean_transaction_detail(t) for t in transactions]
        all_transactions.extend(cleaned_transactions)
        
        if i % 100 == 0 or i == num_pages - 1:
            write_to_csv(all_transactions)
            all_transactions = []

print(f"Successfully processed and saved all transactions to the file {output_file_path}")
# Out:
# Processing page 1
# Processing page 2
# Processing page 3
# Processing page 4
# Processing page 5
# Processing page 6
# Processing page 7
# Processing page 8
# Processing page 9
# Processing page 10
# Processing page 11
# Processing page 12
# Processing page 13
# Processing page 14
# Processing page 15
# Processing page 16
# Processing page 17
# Processing page 18
# Processing page 19
# Processing page 20
# Processing page 21
# Processing page 22
# Processing page 23
# Processing page 24
# Processing page 25
# Processing page 26
# Processing page 27
# Processing page 28
# Processing page 29
# Processing page 30
# Processing page 31
# Processing page 32
# Processing page 33
# Processing page 34
# Processing page 35
# Processing page 36
# Processing page 37
# Processing page 38
# Processing page 39
# Processing page 40
# Processing page 41
# Processing page 42
# Processing page 43
# Processing page 44
# Processing page 45
# Processing page 46
# Processing page 47
# Processing page 48
# Processing page 49
# Processing page 50
# Processing page 51
# Processing page 52
# Processing page 53
# Processing page 54
# Processing page 55
# Processing page 56
# Processing page 57
# Processing page 58
# Processing page 59
# Processing page 60
# Processing page 61
# Processing page 62
# Processing page 63
# Processing page 64
# Processing page 65
# Processing page 66
# Processing page 67
# Processing page 68
# Processing page 69
# Processing page 70
# Processing page 71
# Processing page 72
# Processing page 73
# Processing page 74
# Processing page 75
# Processing page 76
# Processing page 77
# Processing page 78
# Processing page 79
# Processing page 80
# Processing page 81
# Processing page 82
# Processing page 83
# Processing page 84
# Processing page 85
# Processing page 86
# Processing page 87
# Processing page 88
# Processing page 89
# Processing page 90
# Processing page 91
# Processing page 92
# Processing page 93
# Processing page 94
# Processing page 95
# Processing page 96
# Processing page 97
# Processing page 98
# Processing page 99
# Processing page 100
# Processing page 101
# Processing page 102
# Processing page 103
# Processing page 104
# Processing page 105
# Processing page 106
# Processing page 107
# Processing page 108
# Processing page 109
# Processing page 110
# Processing page 111
# Processing page 112
# Processing page 113
# Processing page 114
# Processing page 115
# Processing page 116
# Processing page 117
# Processing page 118
# Processing page 119
# Processing page 120
# Processing page 121
# Processing page 122
# Processing page 123
# Processing page 124
# Processing page 125
# Processing page 126
# Processing page 127
# Processing page 128
# Processing page 129
# Processing page 130
# Processing page 131
# Processing page 132
# Processing page 133
# Processing page 134
# Processing page 135
# Processing page 136
# Processing page 137
# Processing page 138
# Processing page 139
# Processing page 140
# Processing page 141
# Processing page 142
# Processing page 143
# Processing page 144
# Processing page 145
# Processing page 146
# Processing page 147
# Processing page 148
# Processing page 149
# Processing page 150
# Processing page 151
# Processing page 152
# Processing page 153
# Processing page 154
# Processing page 155
# Processing page 156
# Processing page 157
# Processing page 158
# Processing page 159
# Processing page 160
# Processing page 161
# Processing page 162
# Processing page 163
# Processing page 164
# Processing page 165
# Processing page 166
# Processing page 167
# Processing page 168
# Processing page 169
# Processing page 170
# Processing page 171
# Processing page 172
# Processing page 173
# Processing page 174
# Processing page 175
# Processing page 176
# Processing page 177
# Processing page 178
# Processing page 179
# Processing page 180
# Processing page 181
# Processing page 182
# Processing page 183
# Processing page 184
# Processing page 185
# Processing page 186
# Processing page 187
# Processing page 188
# Processing page 189
# Processing page 190
# Processing page 191
# Processing page 192
# Processing page 193
# Processing page 194
# Processing page 195
# Processing page 196
# Processing page 197
# Processing page 198
# Processing page 199
# Processing page 200
# Processing page 201
# Processing page 202
# Processing page 203
# Processing page 204
# Processing page 205
# Processing page 206
# Processing page 207
# Processing page 208
# Processing page 209
# Processing page 210
# Processing page 211
# Processing page 212
# Processing page 213
# Processing page 214
# Processing page 215
# Processing page 216
# Processing page 217
# Processing page 218
# Processing page 219
# Processing page 220
# Processing page 221
# Processing page 222
# Processing page 223
# Processing page 224
# Processing page 225
# Processing page 226
# Processing page 227
# Processing page 228
# Processing page 229
# Processing page 230
# Processing page 231
# Processing page 232
# Processing page 233
# Processing page 234
# Processing page 235
# Processing page 236
# Processing page 237
# Processing page 238
# Processing page 239
# Processing page 240
# Processing page 241
# Processing page 242
# Processing page 243
# Processing page 244
# Processing page 245
# Processing page 246
# Processing page 247
# Processing page 248
# Processing page 249
# Processing page 250
# Processing page 251
# Processing page 252
# Processing page 253
# Processing page 254
# Processing page 255
# Processing page 256
# Processing page 257
# Processing page 258
# Processing page 259
# Processing page 260
# Processing page 261
# Processing page 262
# Processing page 263
# Processing page 264
# Processing page 265
# Processing page 266
# Processing page 267
# Processing page 268
# Processing page 269
# Processing page 270
# Processing page 271
# Processing page 272
# Processing page 273
# Processing page 274
# Processing page 275
# Processing page 276
# Processing page 277
# Processing page 278
# Processing page 279
# Processing page 280
# Processing page 281
# Processing page 282
# Processing page 283
# Processing page 284
# Processing page 285
# Processing page 286
# Processing page 287
# Processing page 288
# Processing page 289
# Processing page 290
# Processing page 291
# Processing page 292
# Processing page 293
# Processing page 294
# Processing page 295
# Processing page 296
# Processing page 297
# Processing page 298
# Processing page 299
# Processing page 300
# Processing page 301
# Processing page 302
# Processing page 303
# Processing page 304
# Processing page 305
# Processing page 306
# Processing page 307
# Processing page 308
# Processing page 309
# Processing page 310
# Processing page 311
# Processing page 312
# Processing page 313
# Processing page 314
# Processing page 315
# Processing page 316
# Processing page 317
# Processing page 318
# Processing page 319
# Processing page 320
# Processing page 321
# Processing page 322
# Processing page 323
# Processing page 324
# Processing page 325
# Processing page 326
# Processing page 327
# Processing page 328
# Processing page 329
# Processing page 330
# Processing page 331
# Processing page 332
# Processing page 333
# Processing page 334
# Processing page 335
# Processing page 336
# Processing page 337
# Processing page 338
# Processing page 339
# Processing page 340
# Processing page 341
# Processing page 342
# Processing page 343
# Processing page 344
# Processing page 345
# Processing page 346
# Processing page 347
# Processing page 348
# Processing page 349
# Processing page 350
# Processing page 351
# Processing page 352
# Processing page 353
# Processing page 354
# Processing page 355
# Processing page 356
# Processing page 357
# Processing page 358
# Processing page 359
# Processing page 360
# Processing page 361
# Processing page 362
# Processing page 363
# Processing page 364
# Processing page 365
# Processing page 366
# Processing page 367
# Processing page 368
# Processing page 369
# Processing page 370
# Processing page 371
# Processing page 372
# Processing page 373
# Processing page 374
# Processing page 375
# Processing page 376
# Processing page 377
# Processing page 378
# Processing page 379
# Processing page 380
# Processing page 381
# Processing page 382
# Processing page 383
# Processing page 384
# Processing page 385
# Processing page 386
# Processing page 387
# Processing page 388
# Processing page 389
# Processing page 390
# Processing page 391
# Processing page 392
# Processing page 393
# Processing page 394
# Processing page 395
# Processing page 396
# Processing page 397
# Processing page 398
# Processing page 399
# Processing page 400
# Processing page 401
# Processing page 402
# Processing page 403
# Processing page 404
# Processing page 405
# Processing page 406
# Processing page 407
# Processing page 408
# Processing page 409
# Processing page 410
# Processing page 411
# Processing page 412
# Processing page 413
# Processing page 414
# Processing page 415
# Processing page 416
# Processing page 417
# Processing page 418
# Processing page 419
# Processing page 420
# Processing page 421
# Processing page 422
# Processing page 423
# Processing page 424
# Processing page 425
# Processing page 426
# Processing page 427
# Processing page 428
# Processing page 429
# Processing page 430
# Processing page 431
# Processing page 432
# Processing page 433
# Processing page 434
# Processing page 435
# Processing page 436
# Processing page 437
# Processing page 438
# Processing page 439
# Processing page 440
# Processing page 441
# Processing page 442
# Processing page 443
# Processing page 444
# Processing page 445
# Processing page 446
# Processing page 447
# Processing page 448
# Processing page 449
# Processing page 450
# Processing page 451
# Processing page 452
# Processing page 453
# Processing page 454
# Processing page 455
# Processing page 456
# Processing page 457
# Processing page 458
# Processing page 459
# Processing page 460
# Processing page 461
# Processing page 462
# Processing page 463
# Processing page 464
# Processing page 465
# Processing page 466
# Processing page 467
# Processing page 468
# Processing page 469
# Processing page 470
# Processing page 471
# Processing page 472
# Processing page 473
# Processing page 474
# Processing page 475
# Processing page 476
# Processing page 477
# Processing page 478
# Processing page 479
# Processing page 480
# Processing page 481
# Processing page 482
# Processing page 483
# Processing page 484
# Processing page 485
# Processing page 486
# Processing page 487
# Processing page 488
# Processing page 489
# Processing page 490
# Processing page 491
# Processing page 492
# Processing page 493
# Processing page 494
# Processing page 495
# Processing page 496
# Processing page 497
# Processing page 498
# Processing page 499
# Processing page 500
# Processing page 501
# Processing page 502
# Processing page 503
# Processing page 504
# Processing page 505
# Processing page 506
# Processing page 507
# Processing page 508
# Processing page 509
# Processing page 510
# Processing page 511
# Processing page 512
# Processing page 513
# Processing page 514
# Processing page 515
# Processing page 516
# Processing page 517
# Processing page 518
# Processing page 519
# Processing page 520
# Processing page 521
# Processing page 522
# Processing page 523
# Processing page 524
# Processing page 525
# Processing page 526
# Processing page 527
# Processing page 528
# Processing page 529
# Processing page 530
# Processing page 531
# Processing page 532
# Processing page 533
# Processing page 534
# Processing page 535
# Processing page 536
# Processing page 537
# Processing page 538
# Processing page 539
# Processing page 540
# Processing page 541
# Processing page 542
# Processing page 543
# Processing page 544
# Processing page 545
# Processing page 546
# Processing page 547
# Processing page 548
# Processing page 549
# Processing page 550
# Processing page 551
# Processing page 552
# Processing page 553
# Processing page 554
# Processing page 555
# Processing page 556
# Processing page 557
# Processing page 558
# Processing page 559
# Processing page 560
# Processing page 561
# Processing page 562
# Processing page 563
# Processing page 564
# Processing page 565
# Processing page 566
# Processing page 567
# Processing page 568
# Processing page 569
# Processing page 570
# Processing page 571
# Processing page 572
# Processing page 573
# Processing page 574
# Processing page 575
# Processing page 576
# Processing page 577
# Processing page 578
# Processing page 579
# Processing page 580
# Processing page 581
# Processing page 582
# Processing page 583
# Processing page 584
# Processing page 585
# Processing page 586
# Processing page 587
# Processing page 588
# Processing page 589
# Processing page 590
# Processing page 591
# Processing page 592
# Processing page 593
# Processing page 594
# Processing page 595
# Processing page 596
# Processing page 597
# Processing page 598
# Processing page 599
# Processing page 600
# Processing page 601
# Processing page 602
# Processing page 603
# Processing page 604
# Processing page 605
# Processing page 606
# Processing page 607
# Processing page 608
# Processing page 609
# Processing page 610
# Processing page 611
# Processing page 612
# Processing page 613
# Processing page 614
# Processing page 615
# Processing page 616
# Processing page 617
# Processing page 618
# Processing page 619
# Processing page 620
# Processing page 621
# Processing page 622
# Processing page 623
# Processing page 624
# Processing page 625
# Processing page 626
# Processing page 627
# Processing page 628
# Processing page 629
# Processing page 630
# Processing page 631
# Processing page 632
# Processing page 633
# Processing page 634
# Processing page 635
# Processing page 636
# Processing page 637
# Processing page 638
# Processing page 639
# Processing page 640
# Processing page 641
# Processing page 642
# Processing page 643
# Processing page 644
# Processing page 645
# Processing page 646
# Processing page 647
# Processing page 648
# Processing page 649
# Processing page 650
# Processing page 651
# Processing page 652
# Processing page 653
# Processing page 654
# Processing page 655
# Processing page 656
# Processing page 657
# Processing page 658
# Processing page 659
# Processing page 660
# Processing page 661
# Processing page 662
# Processing page 663
# Processing page 664
# Processing page 665
# Processing page 666
# Processing page 667
# Processing page 668
# Processing page 669
# Processing page 670
# Processing page 671
# Processing page 672
# Processing page 673
# Processing page 674
# Processing page 675
# Processing page 676
# Processing page 677
# Processing page 678
# Processing page 679
# Processing page 680
# Processing page 681
# Processing page 682
# Processing page 683
# Processing page 684
# Processing page 685
# Processing page 686
# Processing page 687
# Processing page 688
# Processing page 689
# Processing page 690
# Processing page 691
# Processing page 692
# Processing page 693
# Processing page 694
# Processing page 695
# Processing page 696
# Processing page 697
# Processing page 698
# Processing page 699
# Processing page 700
# Processing page 701
# Processing page 702
# Processing page 703
# Processing page 704
# Processing page 705
# Processing page 706
# Processing page 707
# Processing page 708
# Processing page 709
# Processing page 710
# Processing page 711
# Processing page 712
# Processing page 713
# Processing page 714
# Processing page 715
# Processing page 716
# Processing page 717
# Processing page 718
# Processing page 719
# Processing page 720
# Processing page 721
# Processing page 722
# Processing page 723
# Processing page 724
# Processing page 725
# Processing page 726
# Processing page 727
# Processing page 728
# Processing page 729
# Processing page 730
# Processing page 731
# Processing page 732
# Processing page 733
# Processing page 734
# Processing page 735
# Processing page 736
# Processing page 737
# Processing page 738
# Processing page 739
# Processing page 740
# Processing page 741
# Processing page 742
# Processing page 743
# Processing page 744
# Processing page 745
# Processing page 746
# Processing page 747
# Processing page 748
# Processing page 749
# Processing page 750
# Processing page 751
# Processing page 752
# Processing page 753
# Processing page 754
# Processing page 755
# Processing page 756
# Processing page 757
# Processing page 758
# Processing page 759
# Processing page 760
# Processing page 761
# Processing page 762
# Processing page 763
# Processing page 764
# Processing page 765
# Processing page 766
# Processing page 767
# Processing page 768
# Processing page 769
# Processing page 770
# Processing page 771
# Processing page 772
# Processing page 773
# Processing page 774
# Processing page 775
# Processing page 776
# Processing page 777
# Processing page 778
# Processing page 779
# Processing page 780
# Processing page 781
# Processing page 782
# Processing page 783
# Processing page 784
# Processing page 785
# Processing page 786
# Processing page 787
# Processing page 788
# Processing page 789
# Processing page 790
# Processing page 791
# Processing page 792
# Processing page 793
# Processing page 794
# Processing page 795
# Processing page 796
# Processing page 797
# Processing page 798
# Processing page 799
# Processing page 800
# Processing page 801
# Processing page 802
# Processing page 803
# Processing page 804
# Processing page 805
# Processing page 806
# Processing page 807
# Processing page 808
# Processing page 809
# Processing page 810
# Processing page 811
# Processing page 812
# Processing page 813
# Processing page 814
# Processing page 815
# Processing page 816
# Processing page 817
# Processing page 818
# Processing page 819
# Processing page 820
# Processing page 821
# Processing page 822
# Processing page 823
# Processing page 824
# Processing page 825
# Processing page 826
# Processing page 827
# Processing page 828
# Processing page 829
# Processing page 830
# Processing page 831
# Processing page 832
# Processing page 833
# Processing page 834
# Processing page 835
# Processing page 836
# Processing page 837
# Processing page 838
# Processing page 839
# Processing page 840
# Processing page 841
# Processing page 842
# Processing page 843
# Processing page 844
# Processing page 845
# Processing page 846
# Processing page 847
# Processing page 848
# Processing page 849
# Processing page 850
# Processing page 851
# Processing page 852
# Processing page 853
# Processing page 854
# Processing page 855
# Processing page 856
# Processing page 857
# Processing page 858
# Processing page 859
# Processing page 860
# Processing page 861
# Processing page 862
# Processing page 863
# Processing page 864
# Processing page 865
# Processing page 866
# Processing page 867
# Processing page 868
# Processing page 869
# Processing page 870
# Processing page 871
# Processing page 872
# Processing page 873
# Processing page 874
# Processing page 875
# Processing page 876
# Processing page 877
# Processing page 878
# Processing page 879
# Processing page 880
# Processing page 881
# Processing page 882
# Processing page 883
# Processing page 884
# Processing page 885
# Processing page 886
# Processing page 887
# Processing page 888
# Processing page 889
# Processing page 890
# Processing page 891
# Processing page 892
# Processing page 893
# Processing page 894
# Processing page 895
# Processing page 896
# Processing page 897
# Processing page 898
# Processing page 899
# Processing page 900
# Processing page 901
# Processing page 902
# Processing page 903
# Processing page 904
# Processing page 905
# Processing page 906
# Processing page 907
# Processing page 908
# Processing page 909
# Processing page 910
# Processing page 911
# Processing page 912
# Processing page 913
# Processing page 914
# Processing page 915
# Processing page 916
# Processing page 917
# Processing page 918
# Processing page 919
# Processing page 920
# Processing page 921
# Processing page 922
# Processing page 923
# Processing page 924
# Processing page 925
# Processing page 926
# Processing page 927
# Processing page 928
# Processing page 929
# Processing page 930
# Processing page 931
# Processing page 932
# Processing page 933
# Processing page 934
# Processing page 935
# Processing page 936
# Processing page 937
# Processing page 938
# Processing page 939
# Processing page 940
# Processing page 941
# Processing page 942
# Processing page 943
# Processing page 944
# Processing page 945
# Processing page 946
# Processing page 947
# Processing page 948
# Processing page 949
# Processing page 950
# Processing page 951
# Processing page 952
# Processing page 953
# Processing page 954
# Processing page 955
# Processing page 956
# Processing page 957
# Processing page 958
# Processing page 959
# Processing page 960
# Processing page 961
# Processing page 962
# Processing page 963
# Processing page 964
# Processing page 965
# Processing page 966
# Processing page 967
# Processing page 968
# Processing page 969
# Processing page 970
# Processing page 971
# Processing page 972
# Processing page 973
# Processing page 974
# Processing page 975
# Processing page 976
# Processing page 977
# Processing page 978
# Processing page 979
# Processing page 980
# Processing page 981
# Processing page 982
# Processing page 983
# Processing page 984
# Processing page 985
# Processing page 986
# Processing page 987
# Processing page 988
# Processing page 989
# Processing page 990
# Processing page 991
# Processing page 992
# Processing page 993
# Processing page 994
# Processing page 995
# Processing page 996
# Processing page 997
# Processing page 998
# Processing page 999
# Processing page 1000
# Processing page 1001
# Processing page 1002
# Processing page 1003
# Processing page 1004
# Processing page 1005
# Processing page 1006
# Processing page 1007
# Processing page 1008
# Processing page 1009
# Processing page 1010
# Processing page 1011
# Processing page 1012
# Processing page 1013
# Processing page 1014
# Processing page 1015
# Processing page 1016
# Processing page 1017
# Processing page 1018
# Processing page 1019
# Processing page 1020
# Processing page 1021
# Processing page 1022
# Processing page 1023
# Processing page 1024
# Processing page 1025
# Processing page 1026
# Processing page 1027
# Processing page 1028
# Processing page 1029
# Processing page 1030
# Processing page 1031
# Processing page 1032
# Processing page 1033
# Processing page 1034
# Processing page 1035
# Processing page 1036
# Processing page 1037
# Processing page 1038
# Processing page 1039
# Processing page 1040
# Processing page 1041
# Processing page 1042
# Processing page 1043
# Processing page 1044
# Processing page 1045
# Processing page 1046
# Processing page 1047
# Processing page 1048
# Processing page 1049
# Processing page 1050
# Processing page 1051
# Processing page 1052
# Processing page 1053
# Processing page 1054
# Processing page 1055
# Processing page 1056
# Processing page 1057
# Processing page 1058
# Processing page 1059
# Processing page 1060
# Processing page 1061
# Processing page 1062
# Processing page 1063
# Processing page 1064
# Processing page 1065
# Processing page 1066
# Processing page 1067
# Processing page 1068
# Processing page 1069
# Processing page 1070
# Processing page 1071
# Processing page 1072
# Processing page 1073
# Processing page 1074
# Processing page 1075
# Processing page 1076
# Processing page 1077
# Processing page 1078
# Processing page 1079
# Processing page 1080
# Processing page 1081
# Processing page 1082
# Processing page 1083
# Processing page 1084
# Processing page 1085
# Processing page 1086
# Processing page 1087
# Processing page 1088
# Processing page 1089
# Processing page 1090
# Processing page 1091
# Processing page 1092
# Processing page 1093
# Processing page 1094
# Processing page 1095
# Processing page 1096
# Processing page 1097
# Processing page 1098
# Processing page 1099
# Processing page 1100
# Processing page 1101
# Processing page 1102
# Processing page 1103
# Processing page 1104
# Processing page 1105
# Processing page 1106
# Processing page 1107
# Processing page 1108
# Processing page 1109
# Processing page 1110
# Processing page 1111
# Processing page 1112
# Processing page 1113
# Processing page 1114
# Processing page 1115
# Processing page 1116
# Processing page 1117
# Processing page 1118
# Processing page 1119
# Processing page 1120
# Processing page 1121
# Processing page 1122
# Processing page 1123
# Processing page 1124
# Processing page 1125
# Processing page 1126
# Processing page 1127
# Processing page 1128
# Processing page 1129
# Processing page 1130
# Processing page 1131
# Processing page 1132
# Processing page 1133
# Processing page 1134
# Processing page 1135
# Processing page 1136
# Processing page 1137
# Processing page 1138
# Processing page 1139
# Processing page 1140
# Processing page 1141
# Processing page 1142
# Processing page 1143
# Processing page 1144
# Processing page 1145
# Processing page 1146
# Processing page 1147
# Processing page 1148
# Processing page 1149
# Processing page 1150
# Processing page 1151
# Processing page 1152
# Processing page 1153
# Processing page 1154
# Processing page 1155
# Processing page 1156
# Processing page 1157
# Processing page 1158
# Processing page 1159
# Processing page 1160
# Processing page 1161
# Processing page 1162
# Processing page 1163
# Processing page 1164
# Processing page 1165
# Processing page 1166
# Processing page 1167
# Processing page 1168
# Processing page 1169
# Processing page 1170
# Processing page 1171
# Processing page 1172
# Processing page 1173
# Processing page 1174
# Processing page 1175
# Processing page 1176
# Processing page 1177
# Processing page 1178
# Processing page 1179
# Processing page 1180
# Processing page 1181
# Processing page 1182
# Processing page 1183
# Processing page 1184
# Processing page 1185
# Processing page 1186
# Processing page 1187
# Processing page 1188
# Processing page 1189
# Processing page 1190
# Processing page 1191
# Processing page 1192
# Processing page 1193
# Processing page 1194
# Processing page 1195
# Processing page 1196
# Processing page 1197
# Processing page 1198
# Processing page 1199
# Processing page 1200
# Processing page 1201
# Processing page 1202
# Processing page 1203
# Processing page 1204
# Processing page 1205
# Processing page 1206
# Processing page 1207
# Processing page 1208
# Processing page 1209
# Processing page 1210
# Processing page 1211
# Processing page 1212
# Processing page 1213
# Processing page 1214
# Processing page 1215
# Processing page 1216
# Processing page 1217
# Processing page 1218
# Processing page 1219
# Processing page 1220
# Processing page 1221
# Processing page 1222
# Processing page 1223
# Processing page 1224
# Processing page 1225
# Processing page 1226
# Processing page 1227
# Processing page 1228
# Processing page 1229
# Processing page 1230
# Processing page 1231
# Processing page 1232
# Processing page 1233
# Processing page 1234
# Processing page 1235
# Processing page 1236
# Processing page 1237
# Processing page 1238
# Processing page 1239
# Processing page 1240
# Processing page 1241
# Processing page 1242
# Processing page 1243
# Processing page 1244
# Processing page 1245
# Processing page 1246
# Processing page 1247
# Processing page 1248
# Processing page 1249
# Processing page 1250
# Processing page 1251
# Processing page 1252
# Processing page 1253
# Processing page 1254
# Processing page 1255
# Processing page 1256
# Processing page 1257
# Processing page 1258
# Processing page 1259
# Processing page 1260
# Processing page 1261
# Processing page 1262
# Processing page 1263
# Processing page 1264
# Processing page 1265
# Processing page 1266
# Processing page 1267
# Processing page 1268
# Processing page 1269
# Processing page 1270
# Processing page 1271
# Processing page 1272
# Processing page 1273
# Processing page 1274
# Processing page 1275
# Processing page 1276
# Processing page 1277
# Processing page 1278
# Processing page 1279
# Processing page 1280
# Processing page 1281
# Processing page 1282
# Processing page 1283
# Processing page 1284
# Processing page 1285
# Processing page 1286
# Processing page 1287
# Processing page 1288
# Processing page 1289
# Processing page 1290
# Processing page 1291
# Processing page 1292
# Processing page 1293
# Processing page 1294
# Processing page 1295
# Processing page 1296
# Processing page 1297
# Processing page 1298
# Processing page 1299
# Processing page 1300
# Processing page 1301
# Processing page 1302
# Processing page 1303
# Processing page 1304
# Processing page 1305
# Processing page 1306
# Processing page 1307
# Processing page 1308
# Processing page 1309
# Processing page 1310
# Processing page 1311
# Processing page 1312
# Processing page 1313
# Processing page 1314
# Processing page 1315
# Processing page 1316
# Processing page 1317
# Processing page 1318
# Processing page 1319
# Processing page 1320
# Processing page 1321
# Processing page 1322
# Processing page 1323
# Processing page 1324
# Processing page 1325
# Processing page 1326
# Processing page 1327
# Processing page 1328
# Processing page 1329
# Processing page 1330
# Processing page 1331
# Processing page 1332
# Processing page 1333
# Processing page 1334
# Processing page 1335
# Processing page 1336
# Processing page 1337
# Processing page 1338
# Processing page 1339
# Processing page 1340
# Processing page 1341
# Processing page 1342
# Processing page 1343
# Processing page 1344
# Processing page 1345
# Processing page 1346
# Processing page 1347
# Processing page 1348
# Processing page 1349
# Processing page 1350
# Processing page 1351
# Processing page 1352
# Processing page 1353
# Processing page 1354
# Processing page 1355
# Processing page 1356
# Processing page 1357
# Processing page 1358
# Processing page 1359
# Processing page 1360
# Processing page 1361
# Processing page 1362
# Processing page 1363
# Processing page 1364
# Processing page 1365
# Processing page 1366
# Processing page 1367
# Processing page 1368
# Processing page 1369
# Processing page 1370
# Processing page 1371
# Processing page 1372
# Processing page 1373
# Processing page 1374
# Processing page 1375
# Processing page 1376
# Processing page 1377
# Processing page 1378
# Processing page 1379
# Processing page 1380
# Processing page 1381
# Processing page 1382
# Processing page 1383
# Processing page 1384
# Processing page 1385
# Processing page 1386
# Processing page 1387
# Processing page 1388
# Processing page 1389
# Processing page 1390
# Processing page 1391
# Processing page 1392
# Processing page 1393
# Processing page 1394
# Processing page 1395
# Processing page 1396
# Processing page 1397
# Processing page 1398
# Processing page 1399
# Processing page 1400
# Processing page 1401
# Processing page 1402
# Processing page 1403
# Processing page 1404
# Processing page 1405
# Processing page 1406
# Processing page 1407
# Processing page 1408
# Processing page 1409
# Processing page 1410
# Processing page 1411
# Processing page 1412
# Processing page 1413
# Processing page 1414
# Processing page 1415
# Processing page 1416
# Processing page 1417
# Processing page 1418
# Processing page 1419
# Processing page 1420
# Processing page 1421
# Processing page 1422
# Processing page 1423
# Processing page 1424
# Processing page 1425
# Processing page 1426
# Processing page 1427
# Processing page 1428
# Processing page 1429
# Processing page 1430
# Processing page 1431
# Processing page 1432
# Processing page 1433
# Processing page 1434
# Processing page 1435
# Processing page 1436
# Processing page 1437
# Processing page 1438
# Processing page 1439
# Processing page 1440
# Processing page 1441
# Processing page 1442
# Processing page 1443
# Processing page 1444
# Processing page 1445
# Processing page 1446
# Processing page 1447
# Processing page 1448
# Processing page 1449
# Processing page 1450
# Processing page 1451
# Processing page 1452
# Processing page 1453
# Processing page 1454
# Processing page 1455
# Processing page 1456
# Processing page 1457
# Processing page 1458
# Processing page 1459
# Processing page 1460
# Processing page 1461
# Processing page 1462
# Processing page 1463
# Processing page 1464
# Processing page 1465
# Processing page 1466
# Processing page 1467
# Processing page 1468
# Processing page 1469
# Processing page 1470
# Processing page 1471
# Processing page 1472
# Processing page 1473
# Processing page 1474
# Processing page 1475
# Processing page 1476
# Processing page 1477
# Processing page 1478
# Processing page 1479
# Processing page 1480
# Processing page 1481
# Processing page 1482
# Processing page 1483
# Processing page 1484
# Processing page 1485
# Processing page 1486
# Processing page 1487
# Processing page 1488
# Processing page 1489
# Processing page 1490
# Processing page 1491
# Processing page 1492
# Processing page 1493
# Processing page 1494
# Processing page 1495
# Processing page 1496
# Processing page 1497
# Processing page 1498
# Processing page 1499
# Processing page 1500
# Processing page 1501
# Processing page 1502
# Processing page 1503
# Processing page 1504
# Processing page 1505
# Processing page 1506
# Processing page 1507
# Processing page 1508
# Processing page 1509
# Processing page 1510
# Processing page 1511
# Processing page 1512
# Processing page 1513
# Processing page 1514
# Processing page 1515
# Processing page 1516
# Processing page 1517
# Processing page 1518
# Processing page 1519
# Processing page 1520
# Processing page 1521
# Processing page 1522
# Processing page 1523
# Processing page 1524
# Processing page 1525
# Processing page 1526
# Processing page 1527
# Processing page 1528
# Processing page 1529
# Processing page 1530
# Processing page 1531
# Processing page 1532
# Processing page 1533
# Processing page 1534
# Processing page 1535
# Processing page 1536
# Processing page 1537
# Processing page 1538
# Processing page 1539
# Processing page 1540
# Processing page 1541
# Processing page 1542
# Processing page 1543
# Processing page 1544
# Processing page 1545
# Processing page 1546
# Processing page 1547
# Processing page 1548
# Processing page 1549
# Processing page 1550
# Processing page 1551
# Processing page 1552
# Processing page 1553
# Processing page 1554
# Processing page 1555
# Processing page 1556
# Processing page 1557
# Processing page 1558
# Processing page 1559
# Processing page 1560
# Processing page 1561
# Processing page 1562
# Processing page 1563
# Processing page 1564
# Processing page 1565
# Processing page 1566
# Processing page 1567
# Processing page 1568
# Processing page 1569
# Processing page 1570
# Processing page 1571
# Processing page 1572
# Processing page 1573
# Processing page 1574
# Processing page 1575
# Processing page 1576
# Processing page 1577
# Processing page 1578
# Processing page 1579
# Processing page 1580
# Processing page 1581
# Processing page 1582
# Processing page 1583
# Processing page 1584
# Processing page 1585
# Processing page 1586
# Processing page 1587
# Processing page 1588
# Processing page 1589
# Processing page 1590
# Processing page 1591
# Processing page 1592
# Processing page 1593
# Processing page 1594
# Processing page 1595
# Processing page 1596
# Processing page 1597
# Processing page 1598
# Processing page 1599
# Processing page 1600
# Processing page 1601
# Processing page 1602
# Processing page 1603
# Processing page 1604
# Processing page 1605
# Processing page 1606
# Processing page 1607
# Processing page 1608
# Processing page 1609
# Processing page 1610
# Processing page 1611
# Processing page 1612
# Processing page 1613
# Processing page 1614
# Processing page 1615
# Processing page 1616
# Processing page 1617
# Processing page 1618
# Processing page 1619
# Processing page 1620
# Processing page 1621
# Processing page 1622
# Processing page 1623
# Processing page 1624
# Processing page 1625
# Processing page 1626
# Processing page 1627
# Processing page 1628
# Processing page 1629
# Processing page 1630
# Processing page 1631
# Processing page 1632
# Processing page 1633
# Processing page 1634
# Processing page 1635
# Processing page 1636
# Processing page 1637
# Processing page 1638
# Processing page 1639
# Processing page 1640
# Processing page 1641
# Processing page 1642
# Processing page 1643
# Processing page 1644
# Processing page 1645
# Processing page 1646
# Processing page 1647
# Processing page 1648
# Processing page 1649
# Processing page 1650
# Processing page 1651
# Processing page 1652
# Processing page 1653
# Processing page 1654
# Processing page 1655
# Processing page 1656
# Processing page 1657
# Processing page 1658
# Processing page 1659
# Processing page 1660
# Processing page 1661
# Processing page 1662
# Processing page 1663
# Processing page 1664
# Processing page 1665
# Processing page 1666
# Processing page 1667
# Processing page 1668
# Processing page 1669
# Processing page 1670
# Processing page 1671
# Processing page 1672
# Processing page 1673
# Processing page 1674
# Processing page 1675
# Processing page 1676
# Processing page 1677
# Processing page 1678
# Processing page 1679
# Processing page 1680
# Processing page 1681
# Processing page 1682
# Processing page 1683
# Processing page 1684
# Processing page 1685
# Processing page 1686
# Processing page 1687
# Processing page 1688
# Processing page 1689
# Processing page 1690
# Processing page 1691
# Processing page 1692
# Processing page 1693
# Processing page 1694
# Processing page 1695
# Processing page 1696
# Processing page 1697
# Processing page 1698
# Processing page 1699
# Processing page 1700
# Processing page 1701
# Processing page 1702
# Processing page 1703
# Processing page 1704
# Processing page 1705
# Processing page 1706
# Processing page 1707
# Processing page 1708
# Processing page 1709
# Processing page 1710
# Processing page 1711
# Processing page 1712
# Processing page 1713
# Processing page 1714
# Processing page 1715
# Processing page 1716
# Processing page 1717
# Processing page 1718
# Processing page 1719
# Processing page 1720
# Processing page 1721
# Processing page 1722
# Processing page 1723
# Processing page 1724
# Processing page 1725
# Processing page 1726
# Processing page 1727
# Processing page 1728
# Processing page 1729
# Processing page 1730
# Processing page 1731
# Processing page 1732
# Processing page 1733
# Processing page 1734
# Processing page 1735
# Processing page 1736
# Processing page 1737
# Processing page 1738
# Processing page 1739
# Processing page 1740
# Processing page 1741
# Processing page 1742
# Processing page 1743
# Processing page 1744
# Processing page 1745
# Processing page 1746
# Processing page 1747
# Processing page 1748
# Processing page 1749
# Processing page 1750
# Processing page 1751
# Processing page 1752
# Processing page 1753
# Processing page 1754
# Processing page 1755
# Processing page 1756
# Processing page 1757
# Processing page 1758
# Processing page 1759
# Processing page 1760
# Processing page 1761
# Processing page 1762
# Processing page 1763
# Processing page 1764
# Processing page 1765
# Processing page 1766
# Processing page 1767
# Processing page 1768
# Processing page 1769
# Processing page 1770
# Processing page 1771
# Processing page 1772
# Processing page 1773
# Processing page 1774
# Processing page 1775
# Processing page 1776
# Processing page 1777
# Processing page 1778
# Processing page 1779
# Processing page 1780
# Processing page 1781
# Processing page 1782
# Processing page 1783
# Processing page 1784
# Processing page 1785
# Processing page 1786
# Processing page 1787
# Processing page 1788
# Processing page 1789
# Processing page 1790
# Processing page 1791
# Processing page 1792
# Processing page 1793
# Processing page 1794
# Processing page 1795
# Processing page 1796
# Processing page 1797
# Processing page 1798
# Processing page 1799
# Processing page 1800
# Processing page 1801
# Processing page 1802
# Processing page 1803
# Processing page 1804
# Processing page 1805
# Processing page 1806
# Processing page 1807
# Processing page 1808
# Processing page 1809
# Processing page 1810
# Processing page 1811
# Processing page 1812
# Processing page 1813
# Processing page 1814
# Processing page 1815
# Processing page 1816
# Processing page 1817
# Processing page 1818
# Processing page 1819
# Processing page 1820
# Processing page 1821
# Processing page 1822
# Processing page 1823
# Processing page 1824
# Processing page 1825
# Processing page 1826
# Processing page 1827
# Processing page 1828
# Processing page 1829
# Processing page 1830
# Processing page 1831
# Processing page 1832
# Processing page 1833
# Processing page 1834
# Processing page 1835
# Processing page 1836
# Processing page 1837
# Processing page 1838
# Processing page 1839
# Processing page 1840
# Processing page 1841
# Processing page 1842
# Processing page 1843
# Processing page 1844
# Processing page 1845
# Processing page 1846
# Processing page 1847
# Processing page 1848
# Processing page 1849
# Processing page 1850
# Processing page 1851
# Processing page 1852
# Processing page 1853
# Processing page 1854
# Processing page 1855
# Processing page 1856
# Processing page 1857
# Processing page 1858
# Processing page 1859
# Processing page 1860
# Processing page 1861
# Processing page 1862
# Processing page 1863
# Processing page 1864
# Processing page 1865
# Processing page 1866
# Processing page 1867
# Processing page 1868
# Processing page 1869
# Processing page 1870
# Processing page 1871
# Processing page 1872
# Processing page 1873
# Processing page 1874
# Processing page 1875
# Processing page 1876
# Processing page 1877
# Processing page 1878
# Processing page 1879
# Processing page 1880
# Processing page 1881
# Processing page 1882
# Processing page 1883
# Processing page 1884
# Processing page 1885
# Processing page 1886
# Processing page 1887
# Processing page 1888
# Processing page 1889
# Processing page 1890
# Processing page 1891
# Processing page 1892
# Processing page 1893
# Processing page 1894
# Processing page 1895
# Processing page 1896
# Processing page 1897
# Processing page 1898
# Processing page 1899
# Processing page 1900
# Processing page 1901
# Processing page 1902
# Processing page 1903
# Processing page 1904
# Processing page 1905
# Processing page 1906
# Processing page 1907
# Processing page 1908
# Processing page 1909
# Processing page 1910
# Processing page 1911
# Processing page 1912
# Processing page 1913
# Processing page 1914
# Processing page 1915
# Processing page 1916
# Processing page 1917
# Processing page 1918
# Processing page 1919
# Processing page 1920
# Processing page 1921
# Processing page 1922
# Processing page 1923
# Processing page 1924
# Processing page 1925
# Processing page 1926
# Processing page 1927
# Processing page 1928
# Processing page 1929
# Processing page 1930
# Processing page 1931
# Processing page 1932
# Processing page 1933
# Processing page 1934
# Processing page 1935
# Processing page 1936
# Processing page 1937
# Processing page 1938
# Processing page 1939
# Processing page 1940
# Processing page 1941
# Processing page 1942
# Processing page 1943
# Processing page 1944
# Processing page 1945
# Processing page 1946
# Processing page 1947
# Processing page 1948
# Processing page 1949
# Processing page 1950
# Processing page 1951
# Processing page 1952
# Processing page 1953
# Processing page 1954
# Processing page 1955
# Processing page 1956
# Processing page 1957
# Processing page 1958
# Processing page 1959
# Processing page 1960
# Processing page 1961
# Processing page 1962
# Processing page 1963
# Processing page 1964
# Processing page 1965
# Processing page 1966
# Processing page 1967
# Processing page 1968
# Processing page 1969
# Processing page 1970
# Processing page 1971
# Processing page 1972
# Processing page 1973
# Processing page 1974
# Processing page 1975
# Processing page 1976
# Processing page 1977
# Processing page 1978
# Processing page 1979
# Processing page 1980
# Processing page 1981
# Processing page 1982
# Processing page 1983
# Processing page 1984
# Processing page 1985
# Processing page 1986
# Processing page 1987
# Processing page 1988
# Processing page 1989
# Processing page 1990
# Processing page 1991
# Processing page 1992
# Processing page 1993
# Processing page 1994
# Processing page 1995
# Processing page 1996
# Processing page 1997
# Processing page 1998
# Processing page 1999
# Processing page 2000
# Processing page 2001
# Processing page 2002
# Processing page 2003
# Processing page 2004
# Processing page 2005
# Processing page 2006
# Processing page 2007
# Processing page 2008
# Processing page 2009
# Processing page 2010
# Processing page 2011
# Processing page 2012
# Processing page 2013
# Processing page 2014
# Processing page 2015
# Processing page 2016
# Processing page 2017
# Processing page 2018
# Processing page 2019
# Processing page 2020
# Processing page 2021
# Processing page 2022
# Processing page 2023
# Processing page 2024
# Processing page 2025
# Processing page 2026
# Processing page 2027
# Processing page 2028
# Processing page 2029
# Processing page 2030
# Processing page 2031
# Processing page 2032
# Processing page 2033
# Processing page 2034
# Processing page 2035
# Processing page 2036
# Processing page 2037
# Processing page 2038
# Processing page 2039
# Processing page 2040
# Processing page 2041
# Processing page 2042
# Processing page 2043
# Processing page 2044
# Processing page 2045
# Processing page 2046
# Processing page 2047
# Processing page 2048
# Processing page 2049
# Processing page 2050
# Processing page 2051
# Processing page 2052
# Processing page 2053
# Processing page 2054
# Processing page 2055
# Processing page 2056
# Processing page 2057
# Processing page 2058
# Processing page 2059
# Processing page 2060
# Processing page 2061
# Processing page 2062
# Processing page 2063
# Processing page 2064
# Processing page 2065
# Processing page 2066
# Processing page 2067
# Processing page 2068
# Processing page 2069
# Processing page 2070
# Processing page 2071
# Processing page 2072
# Processing page 2073
# Processing page 2074
# Processing page 2075
# Processing page 2076
# Processing page 2077
# Processing page 2078
# Processing page 2079
# Processing page 2080
# Processing page 2081
# Processing page 2082
# Processing page 2083
# Processing page 2084
# Processing page 2085
# Processing page 2086
# Processing page 2087
# Processing page 2088
# Processing page 2089
# Processing page 2090
# Processing page 2091
# Processing page 2092
# Processing page 2093
# Processing page 2094
# Processing page 2095
# Processing page 2096
# Processing page 2097
# Processing page 2098
# Processing page 2099
# Processing page 2100
# Processing page 2101
# Processing page 2102
# Processing page 2103
# Processing page 2104
# Processing page 2105
# Processing page 2106
# Processing page 2107
# Processing page 2108
# Processing page 2109
# Processing page 2110
# Processing page 2111
# Processing page 2112
# Processing page 2113
# Processing page 2114
# Processing page 2115
# Processing page 2116
# Processing page 2117
# Processing page 2118
# Processing page 2119
# Processing page 2120
# Processing page 2121
# Processing page 2122
# Processing page 2123
# Processing page 2124
# Processing page 2125
# Processing page 2126
# Processing page 2127
# Processing page 2128
# Processing page 2129
# Processing page 2130
# Processing page 2131
# Processing page 2132
# Processing page 2133
# Processing page 2134
# Processing page 2135
# Processing page 2136
# Processing page 2137
# Processing page 2138
# Processing page 2139
# Processing page 2140
# Processing page 2141
# Processing page 2142
# Processing page 2143
# Processing page 2144
# Processing page 2145
# Processing page 2146
# Processing page 2147
# Processing page 2148
# Processing page 2149
# Processing page 2150
# Processing page 2151
# Processing page 2152
# Processing page 2153
# Processing page 2154
# Processing page 2155
# Processing page 2156
# Processing page 2157
# Processing page 2158
# Processing page 2159
# Processing page 2160
# Processing page 2161
# Processing page 2162
# Processing page 2163
# Processing page 2164
# Processing page 2165
# Processing page 2166
# Processing page 2167
# Processing page 2168
# Processing page 2169
# Processing page 2170
# Processing page 2171
# Processing page 2172
# Processing page 2173
# Processing page 2174
# Processing page 2175
# Processing page 2176
# Processing page 2177
# Processing page 2178
# Processing page 2179
# Processing page 2180
# Processing page 2181
# Processing page 2182
# Processing page 2183
# Processing page 2184
# Processing page 2185
# Processing page 2186
# Processing page 2187
# Processing page 2188
# Processing page 2189
# Processing page 2190
# Processing page 2191
# Processing page 2192
# Processing page 2193
# Processing page 2194
# Processing page 2195
# Processing page 2196
# Processing page 2197
# Processing page 2198
# Processing page 2199
# Processing page 2200
# Processing page 2201
# Processing page 2202
# Processing page 2203
# Processing page 2204
# Processing page 2205
# Processing page 2206
# Processing page 2207
# Processing page 2208
# Processing page 2209
# Processing page 2210
# Processing page 2211
# Processing page 2212
# Processing page 2213
# Processing page 2214
# Processing page 2215
# Processing page 2216
# Processing page 2217
# Processing page 2218
# Processing page 2219
# Processing page 2220
# Processing page 2221
# Processing page 2222
# Processing page 2223
# Processing page 2224
# Processing page 2225
# Processing page 2226
# Processing page 2227
# Processing page 2228
# Processing page 2229
# Processing page 2230
# Processing page 2231
# Processing page 2232
# Processing page 2233
# Processing page 2234
# Processing page 2235
# Processing page 2236
# Processing page 2237
# Processing page 2238
# Processing page 2239
# Processing page 2240
# Processing page 2241
# Processing page 2242
# Processing page 2243
# Processing page 2244
# Processing page 2245
# Processing page 2246
# Processing page 2247
# Processing page 2248
# Processing page 2249
# Processing page 2250
# Processing page 2251
# Processing page 2252
# Processing page 2253
# Processing page 2254
# Processing page 2255
# Processing page 2256
# Processing page 2257
# Processing page 2258
# Processing page 2259
# Processing page 2260
# Processing page 2261
# Processing page 2262
# Processing page 2263
# Processing page 2264
# Processing page 2265
# Processing page 2266
# Processing page 2267
# Processing page 2268
# Processing page 2269
# Processing page 2270
# Processing page 2271
# Processing page 2272
# Processing page 2273
# Processing page 2274
# Processing page 2275
# Processing page 2276
# Processing page 2277
# Processing page 2278
# Processing page 2279
# Processing page 2280
# Processing page 2281
# Processing page 2282
# Processing page 2283
# Processing page 2284
# Processing page 2285
# Processing page 2286
# Processing page 2287
# Processing page 2288
# Processing page 2289
# Processing page 2290
# Processing page 2291
# Processing page 2292
# Processing page 2293
# Processing page 2294
# Processing page 2295
# Processing page 2296
# Processing page 2297
# Processing page 2298
# Processing page 2299
# Processing page 2300
# Processing page 2301
# Processing page 2302
# Processing page 2303
# Processing page 2304
# Processing page 2305
# Processing page 2306
# Processing page 2307
# Processing page 2308
# Processing page 2309
# Processing page 2310
# Processing page 2311
# Processing page 2312
# Processing page 2313
# Processing page 2314
# Processing page 2315
# Processing page 2316
# Processing page 2317
# Processing page 2318
# Processing page 2319
# Processing page 2320
# Processing page 2321
# Processing page 2322
# Processing page 2323
# Processing page 2324
# Processing page 2325
# Processing page 2326
# Processing page 2327
# Processing page 2328
# Processing page 2329
# Processing page 2330
# Processing page 2331
# Processing page 2332
# Processing page 2333
# Processing page 2334
# Processing page 2335
# Processing page 2336
# Processing page 2337
# Processing page 2338
# Processing page 2339
# Processing page 2340
# Processing page 2341
# Processing page 2342
# Processing page 2343
# Processing page 2344
# Processing page 2345
# Processing page 2346
# Processing page 2347
# Processing page 2348
# Processing page 2349
# Processing page 2350
# Processing page 2351
# Processing page 2352
# Processing page 2353
# Processing page 2354
# Processing page 2355
# Processing page 2356
# Processing page 2357
# Processing page 2358
# Processing page 2359
# Processing page 2360
# Processing page 2361
# Processing page 2362
# Processing page 2363
# Processing page 2364
# Processing page 2365
# Processing page 2366
# Processing page 2367
# Processing page 2368
# Processing page 2369
# Processing page 2370
# Processing page 2371
# Processing page 2372
# Processing page 2373
# Processing page 2374
# Processing page 2375
# Processing page 2376
# Processing page 2377
# Processing page 2378
# Processing page 2379
# Processing page 2380
# Processing page 2381
# Processing page 2382
# Processing page 2383
# Processing page 2384
# Processing page 2385
# Processing page 2386
# Processing page 2387
# Processing page 2388
# Processing page 2389
# Processing page 2390
# Processing page 2391
# Processing page 2392
# Processing page 2393
# Processing page 2394
# Processing page 2395
# Processing page 2396
# Processing page 2397
# Processing page 2398
# Processing page 2399
# Processing page 2400
# Processing page 2401
# Processing page 2402
# Processing page 2403
# Processing page 2404
# Processing page 2405
# Processing page 2406
# Processing page 2407
# Processing page 2408
# Processing page 2409
# Processing page 2410
# Processing page 2411
# Processing page 2412
# Processing page 2413
# Processing page 2414
# Processing page 2415
# Processing page 2416
# Processing page 2417
# Processing page 2418
# Processing page 2419
# Processing page 2420
# Processing page 2421
# Processing page 2422
# Processing page 2423
# Processing page 2424
# Processing page 2425
# Processing page 2426
# Processing page 2427
# Processing page 2428
# Processing page 2429
# Processing page 2430
# Processing page 2431
# Processing page 2432
# Processing page 2433
# Processing page 2434
# Processing page 2435
# Processing page 2436
# Processing page 2437
# Processing page 2438
# Processing page 2439
# Processing page 2440
# Processing page 2441
# Processing page 2442
# Processing page 2443
# Processing page 2444
# Processing page 2445
# Processing page 2446
# Processing page 2447
# Processing page 2448
# Processing page 2449
# Processing page 2450
# Processing page 2451
# Processing page 2452
# Processing page 2453
# Processing page 2454
# Processing page 2455
# Processing page 2456
# Processing page 2457
# Processing page 2458
# Processing page 2459
# Processing page 2460
# Processing page 2461
# Processing page 2462
# Processing page 2463
# Processing page 2464
# Processing page 2465
# Processing page 2466
# Processing page 2467
# Processing page 2468
# Processing page 2469
# Processing page 2470
# Processing page 2471
# Processing page 2472
# Processing page 2473
# Processing page 2474
# Processing page 2475
# Processing page 2476
# Processing page 2477
# Processing page 2478
# Processing page 2479
# Processing page 2480
# Processing page 2481
# Processing page 2482
# Processing page 2483
# Processing page 2484
# Processing page 2485
# Processing page 2486
# Processing page 2487
# Processing page 2488
# Processing page 2489
# Processing page 2490
# Processing page 2491
# Processing page 2492
# Processing page 2493
# Processing page 2494
# Processing page 2495
# Processing page 2496
# Processing page 2497
# Processing page 2498
# Processing page 2499
# Processing page 2500
# Successfully processed and saved all transactions to the file ../data/processed_data/transactions.csv
